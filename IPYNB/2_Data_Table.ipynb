# %%
import streamlit as st
import pandas as pd

import sys
sys.path.append("/Users/a.h.sheikh/Desktop/IND320_Git_Job/IND320_1_Project/IPYNB/utils.ipynb")
# %run utils.ipynb
# Out:
# 2025-09-28 12:38:01.645 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
st.set_page_config(page_title="Data Table", page_icon="📄", layout="wide")
st.title("Data Table")
# Out:
# 2025-09-28 12:38:01.807 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.807 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.840
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/a.h.sheikh/.pyenv/versions/ind320/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-09-28 12:38:01.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
df = load_data()
# Out:
# 2025-09-28 12:38:01.852 No runtime found, using MemoryCacheStorageManager

# %%
st.subheader("Raw data")
st.dataframe(df, use_container_width=True)
# Out:
# 2025-09-28 12:38:01.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.908 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-09-28 12:38:01.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Find datetime-like and numeric columns
date_cols = [c for c in df.columns if any(k in c.lower() for k in ["date", "time", "datetime", "timestamp"])]
date_col = date_cols[0] if date_cols else None
num_cols = [c for c in df.columns if pd.api.types.is_numeric_dtype(df[c])]

# %%
# Show row-wise sparklines (LineChartColumn) for the first month if available
if "month" in df.columns and date_col and num_cols:
    months = sorted([m for m in df["month"].dropna().unique()])
    if months:
        first_month = months[0]
        mdf = df[df["month"] == first_month].copy()

        rows = [{"Metric": col, "First month trend": mdf[col].tolist()} for col in num_cols]
        table = pd.DataFrame(rows)

        y_min = float(pd.concat([mdf[c] for c in num_cols]).min(skipna=True))
        y_max = float(pd.concat([mdf[c] for c in num_cols]).max(skipna=True))

        st.subheader(f"First month — sparklines ({first_month})")
        st.dataframe(
            table,
            column_config={
                "Metric": st.column_config.TextColumn("Metric"),
                "First month trend": st.column_config.LineChartColumn(
                    "First month trend",
                    y_min=y_min, y_max=y_max,
                    help="Row-wise sparkline for the first month",
                ),
            },
            use_container_width=True,
            hide_index=True,
        )
    else:
        st.info("No month found to display sparklines.")
else:
    st.info("A date/time column and numeric columns are required to build sparklines.")
# Out:
# 2025-09-28 12:38:01.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.968 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-09-28 12:38:01.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 12:38:01.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
