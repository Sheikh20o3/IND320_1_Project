# %%
import streamlit as st # Imports the Streamlit library.

# %%
st.set_page_config(page_title="About", page_icon="ℹ️") # Configures the browser tab title 
st.title("About this app") # Displays the main title
# Out:
# 2025-09-28 15:09:37.451 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:09:37.452 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:09:37.573
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/a.h.sheikh/.pyenv/versions/ind320/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-09-28 15:09:37.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:09:37.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.markdown("""
**In short:** A small, multi-page Streamlit app for exploring the `open-meteo-subset.csv` dataset.

**What you can do**
- Browse the raw data table.
- See per-row sparklines for the first month (using `st.column_config.LineChartColumn`).
- Build interactive time-series plots with **Plotly** — select a single column or all columns, and filter by month range.

**How it works**
- Reads a **local CSV** and caches it with `st.cache_data` for speed.
- Pages: Home, Data, Plot, About.
- Dependencies (see `requirements.txt`): `streamlit`, `pandas`, `numpy`, `plotly`.
""")
# Out:
# 2025-09-28 15:09:37.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:09:37.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:09:37.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
