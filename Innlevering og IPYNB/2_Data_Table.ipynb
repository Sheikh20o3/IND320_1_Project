# %%
import streamlit as st 
import pandas as pd 
from utils import load_data
# Out:
# 2025-09-28 15:24:36.074 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
st.set_page_config(page_title="Data Table", page_icon="📄", layout="wide") # Sets the page title and uses a wide layout.
st.title("Data Table") # Displays the main header.
# Out:
# 2025-09-28 15:24:36.115 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.116 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.253
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/a.h.sheikh/.pyenv/versions/ind320/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-09-28 15:24:36.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
df = load_data() # Loads the DataFrame
# Out:
# 2025-09-28 15:24:36.261 No runtime found, using MemoryCacheStorageManager

# %%
st.subheader("Raw data") # Displays a subheading.
st.dataframe(df, use_container_width=True) # Displays the full raw DataFrame in an interactive Streamlit table.
# Out:
# 2025-09-28 15:24:36.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.334 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-09-28 15:24:36.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Find datetime-like and numeric columns
date_cols = [c for c in df.columns if any(k in c.lower() for k in ["date", "time", "datetime", "timestamp"])] # Identifies columns suitable for time series analysis.
date_col = date_cols[0] if date_cols else None
num_cols = [c for c in df.columns if pd.api.types.is_numeric_dtype(df[c])]

# %%
# Show row-wise sparklines
if "month" in df.columns and date_col and num_cols: # Checks if month, date, numeric data are met.
    months = sorted([m for m in df["month"].dropna().unique()])
    if months:
        first_month = months[0]
        mdf = df[df["month"] == first_month].copy() # Filters the data to include only the first month.

        # Prepare data for the sparkline table: each numeric column becomes a row.
        rows = [{"Metric": col, "First month trend": mdf[col].tolist()} for col in num_cols]
        table = pd.DataFrame(rows)

        # Calculate global min/max across all numeric columns in the first month.
        y_min = float(pd.concat([mdf[c] for c in num_cols]).min(skipna=True))
        y_max = float(pd.concat([mdf[c] for c in num_cols]).max(skipna=True))

        st.subheader(f"First month — sparklines ({first_month})") # Displays a subheading for the sparkline table.
        st.dataframe(
            table,
            column_config={
                "Metric": st.column_config.TextColumn("Metric"), # Configures the 'metric' column as standard text.
                "First month trend": st.column_config.LineChartColumn( 
                    "First month trend",
                    y_min=y_min, y_max=y_max, # Ensures all sparklines share the same y-axis scale for comparison.
                    help="Row-wise sparkline for the first month",
                ),
            },
            use_container_width=True,
            hide_index=True,
        )
    else:
        st.info("No month found to display sparklines.") # Fallback if month column exists but is empty.
else:
    st.info("A date/time column and numeric columns are required to build sparklines.") # Fallback if necessary data types are missing.
# Out:
# 2025-09-28 15:24:36.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.372 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-09-28 15:24:36.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:24:36.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
