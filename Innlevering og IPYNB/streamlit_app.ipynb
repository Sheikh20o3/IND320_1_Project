# %%
import streamlit as st # Imports the Streamlit library 
# %run "../Innlevering og IPYNB/utils.ipynb"
# Out:
# 2025-09-28 15:51:47.371 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
st.set_page_config(page_title="Streamlit MWE", page_icon="🌤️", layout="wide") # Sets the overall configuration
# Out:
# 2025-09-28 15:51:47.454 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.title("Open-Meteo: Overview") # Displays the main title of the application.
st.caption("Explore the `open-meteo-subset.csv` dataset. Use the menu on the left to view the data table with sparklines or an interactive plot.")
# Out:
# 2025-09-28 15:51:47.458 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.538
# ...
#   command:
#
#     streamlit run /Users/a.h.sheikh/.pyenv/versions/ind320/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-09-28 15:51:47.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# Sidebar navigation
st.sidebar.header("Navigation") # Creates a header in the sidebar for the navigation links.
st.sidebar.page_link("pages/2_Data_Table.py", label="📄 Data table") # Adds a link to the "Data table" page 
st.sidebar.page_link("pages/3_Plot.py", label="📈 Plot") # Adds a link to the "Plot" page 
st.sidebar.page_link("pages/4_About.py", label="ℹ️ About") # Adds a link to the "About" page
# Out:
# 2025-09-28 15:51:47.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-28 15:51:47.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
def load_data():
    # Sjekk først i samme mappe som utils.py
    path_local = os.path.join(os.path.dirname(__file__), "open-meteo-subset.csv")
    if os.path.exists(path_local):
        path = path_local
    else:
        # Hvis ikke, sjekk i prosjektroten (en mappe opp)
        path_root = os.path.join(os.path.dirname(__file__), "..", "open-meteo-subset.csv")
        if os.path.exists(path_root):
            path = path_root
        else:
            raise FileNotFoundError("Could not find 'open-meteo-subset.csv' in either current folder or project root")
        
    df = load_data() # Loads the data into a DataFrame 
    st.subheader("Quick look at the data") # Displays a subheading for the data preview.
    st.dataframe(df.head(), use_container_width=True) # Shows the first five rows of the DataFrame
    st.success(f"Loaded {len(df)} rows × {len(df.columns)} columns.") # Displays a success message
